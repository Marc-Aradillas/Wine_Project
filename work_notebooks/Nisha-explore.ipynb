# %%
import wrangle as w
import pandas as pd
import numpy as np
import warnings
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings("ignore")

# %%
df = w.clean_wine()
df.head().T
# Out:
#                                             0           1           2  \
# fixed_acidity                             7.4         7.8         7.8
# volatile_acidity                          0.7        0.88        0.76
# citric_acid                               0.0         0.0        0.04
# residual_sugar                            1.9         2.6         2.3
# chlorides                               0.076       0.098       0.092
# free_sulfur_dioxide                      11.0        25.0        15.0
# total_sulfur_dioxide                     34.0        67.0        54.0
# density                                0.9978      0.9968       0.997
# ph                                       3.51         3.2        3.26
# sulphates                                0.56        0.68        0.65
# alcohol                                   9.4         9.8         9.8
# quality                                     5           5           5
# quality_bins                           Medium      Medium      Medium
# alcohol_bins                              Low         Low         Low
# total_sulfur_ratio                   3.090909        2.68         3.6
# acidity_level                             0.0         0.0      0.1304
# sugar_alcohol_ratio                  0.202128    0.265306    0.234694
# chlorides_ph_ratio                   0.021652    0.030625    0.028221
# density_ph_ratio                     0.284274      0.3115    0.305828
# sulfur_dioxide_level                     45.0        92.0        69.0
# sulfates_chlorides_ratio             7.368421    6.938776    7.065217
# ph_bins                                  High      Medium      Medium
# total_acid                               0.56        0.68        0.69
# sulfur_dioxide_chlorides_ratio     447.368421  683.673469  586.956522
# residual_sugar_ph_ratio              0.541311      0.8125    0.705521
# acid_ratio                                0.0         0.0    0.061538
# alcohol_ph_ratio                     2.678063      3.0625    3.006135
# chlorides_density_ratio              0.076168    0.098315    0.092277
# total_sulfur_residual_sugar_ratio   17.894737   25.769231   23.478261
# sulfur_dioxide_percentage           32.352941   37.313433   27.777778
# ph_chlorides_ratio                  46.184211   32.653061   35.434783
# alcohol_sugar_ratio                  4.947368    3.769231     4.26087
# density_sulfates_ratio               1.781786    1.465882    1.533846
# chlorides_sulfates_ratio             0.135714    0.144118    0.141538
# residual_sugar_percentage            5.588235    3.880597    4.259259
# alcohol_chlorides_ratio            123.684211       100.0  106.521739
# density_sulfur_dioxide_ratio         0.029347    0.014878    0.018463
# ph_sulfur_dioxide_ratio              0.103235    0.047761     0.06037
# sulfur_dioxide_sugar_ratio          17.894737   25.769231   23.478261
#
#                                             3           4
# fixed_acidity                            11.2         7.4
# volatile_acidity                         0.28         0.7
# citric_acid                              0.56         0.0
# residual_sugar                            1.9         1.9
# chlorides                               0.075       0.076
# free_sulfur_dioxide                      17.0        11.0
# total_sulfur_dioxide                     60.0        34.0
# density                                 0.998      0.9978
# ph                                       3.16        3.51
# sulphates                                0.58        0.56
# alcohol                                   9.8         9.4
# quality                                     6           5
# quality_bins                           Medium      Medium
# alcohol_bins                              Low         Low
# total_sulfur_ratio                   3.529412    3.090909
# acidity_level                          1.7696         0.0
# sugar_alcohol_ratio                  0.193878    0.202128
# chlorides_ph_ratio                   0.023734    0.021652
# density_ph_ratio                     0.315823    0.284274
# sulfur_dioxide_level                     77.0        45.0
# sulfates_chlorides_ratio             7.733333    7.368421
# ph_bins                                Medium        High
# total_acid                               1.14        0.56
# sulfur_dioxide_chlorides_ratio          800.0  447.368421
# residual_sugar_ph_ratio              0.601266    0.541311
# acid_ratio                           0.965517         0.0
# alcohol_ph_ratio                     3.101266    2.678063
# chlorides_density_ratio               0.07515    0.076168
# total_sulfur_residual_sugar_ratio   31.578947   17.894737
# sulfur_dioxide_percentage           28.333333   32.352941
# ph_chlorides_ratio                  42.133333   46.184211
# alcohol_sugar_ratio                  5.157895    4.947368
# density_sulfates_ratio                1.72069    1.781786
# chlorides_sulfates_ratio              0.12931    0.135714
# residual_sugar_percentage            3.166667    5.588235
# alcohol_chlorides_ratio            130.666667  123.684211
# density_sulfur_dioxide_ratio         0.016633    0.029347
# ph_sulfur_dioxide_ratio              0.052667    0.103235
# sulfur_dioxide_sugar_ratio          31.578947   17.894737

# %%
df = w.clean_wine()

# %%
train, val, test = w.train_val_test(df)

# %%
train, val, test = w.train_val_test(df)

# %%
train.columns.to_list()
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'ph',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'quality_bins',
#  'alcohol_bins',
#  'total_sulfur_ratio',
#  'acidity_level',
#  'sugar_alcohol_ratio',
#  'chlorides_ph_ratio',
#  'density_ph_ratio',
#  'sulfur_dioxide_level',
#  'sulfates_chlorides_ratio',
#  'ph_bins',
#  'total_acid',
#  'sulfur_dioxide_chlorides_ratio',
#  'residual_sugar_ph_ratio',
#  'acid_ratio',
#  'alcohol_ph_ratio',
#  'chlorides_density_ratio',
#  'total_sulfur_residual_sugar_ratio',
#  'sulfur_dioxide_percentage',
#  'ph_chlorides_ratio',
#  'alcohol_sugar_ratio',
#  'density_sulfates_ratio',
#  'chlorides_sulfates_ratio',
#  'residual_sugar_percentage',
#  'alcohol_chlorides_ratio',
#  'density_sulfur_dioxide_ratio',
#  'ph_sulfur_dioxide_ratio',
#  'sulfur_dioxide_sugar_ratio']

# %% [raw]
# mms = MinMaxScaler()

# %%
def scale_data(train, val, test, scaler):
    """
    Scales the numerical columns of the data using the specified scaler.

    Args:
        train (pd.DataFrame): Training data.
        val (pd.DataFrame): Validation data.
        test (pd.DataFrame): Test data.
        scaler (sklearn.preprocessing.Scaler): The scaler to use for data scaling.

    Returns:
        tuple: A tuple containing scaled versions of train, validation, and test DataFrames.
    """
    # Make copies for scaling
    train_scaled = train.copy()
    val_scaled = val.copy()
    test_scaled = test.copy()

    columns_to_scale = ['fixed_acidity',
                         'volatile_acidity',
                         'citric_acid',
                         'residual_sugar',
                         'chlorides',
                         'free_sulfur_dioxide',
                         'total_sulfur_dioxide',
                         'density',
                         'ph',
                         'sulphates',
                         'alcohol',
                         'quality',
                         'total_sulfur_ratio',
                         'acidity_level',
                         'sugar_alcohol_ratio',
                         'chlorides_ph_ratio',
                         'density_ph_ratio',
                         'sulfur_dioxide_level',
                         'sulfates_chlorides_ratio',
                         'total_acid',
                         'sulfur_dioxide_chlorides_ratio',
                         'residual_sugar_ph_ratio',
                         'acid_ratio',
                         'alcohol_ph_ratio',
                         'chlorides_density_ratio',
                         'total_sulfur_residual_sugar_ratio',
                         'sulfur_dioxide_percentage',
                         'ph_chlorides_ratio',
                         'alcohol_sugar_ratio',
                         'density_sulfates_ratio',
                         'chlorides_sulfates_ratio',
                         'residual_sugar_percentage',
                         'alcohol_chlorides_ratio',
                         'density_sulfur_dioxide_ratio',
                         'ph_sulfur_dioxide_ratio',
                         'sulfur_dioxide_sugar_ratio',
                       ]
    
    # Fit the scaler on the training data for all of the columns
    scaler.fit(train[columns_to_scale])
    
    # Transform the data for each split
    train_scaled[columns_to_scale] = scaler.transform(train[columns_to_scale])
    val_scaled[columns_to_scale] = scaler.transform(val[columns_to_scale])
    test_scaled[columns_to_scale] = scaler.transform(test[columns_to_scale])

    scaled_col = [train_scaled, val_scaled, test_scaled]
    
    return train_scaled, val_scaled, test_scaled

# %%
mms = MinMaxScaler()
train_scaled, val_scaled, test_scaled = scale_data(train, val, test, mms)

# %%
train_scaled.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
# 1359       0.661017          0.263333     0.325203        0.012270   0.136213
# 1230       0.330508          0.066667     0.276423        0.032209   0.094684
# 4751       0.322034          0.113333     1.000000        0.061350   0.043189
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
# 1359             0.034364              0.065089  0.191440  0.259843
# 1230             0.096220              0.153846  0.146327  0.496063
# 4751             0.343643              0.852071  0.059186  0.228346
#
#       sulphates  ...  sulfur_dioxide_percentage  ph_chlorides_ratio  \
# 3761   0.125000  ...                   0.173900            0.075112
# 3740   0.159091  ...                   0.295627            0.149447
# 1359   0.244318  ...                   0.233785            0.080423
# 1230   0.318182  ...                   0.287893            0.128921
# 4751   0.119318  ...                   0.183971            0.228332
#
#      alcohol_sugar_ratio density_sulfates_ratio  chlorides_sulfates_ratio  \
# 3761            0.213785               0.438989                  0.291341
# 3740            0.025710               0.373711                  0.149847
# 1359            0.399618               0.257375                  0.196061
# 1230            0.239727               0.192760                  0.104648
# 4751            0.152669               0.449440                  0.099333
#
#       residual_sugar_percentage  alcohol_chlorides_ratio  \
# 3761                   0.020075                 0.062414
# 3740                   0.158298                 0.105107
# 1359                   0.056713                 0.063903
# 1230                   0.052376                 0.110064
# 4751                   0.013506                 0.241747
#
#       density_sulfur_dioxide_ratio  ph_sulfur_dioxide_ratio  \
# 3761                      0.035256                 0.029406
# 3740                      0.034612                 0.036939
# 1359                      0.200384                 0.196294
# 1230                      0.087319                 0.095760
# 4751                      0.002898                 0.002525
#
#       sulfur_dioxide_sugar_ratio
# 3761                    0.230453
# 3740                    0.031590
# 1359                    0.092593
# 1230                    0.099909
# 4751                    0.309447
#
# [5 rows x 39 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

def find_clusters(train_scaled, variable1, variable2, variable3):
    '''
    Inputs:
    train - the dataset
    variable1, variable2, variable3 - feature names as strings in search of potential clusters
    Outputs:
    Plot with clusters & modified train dataframe with an additional 'cluster' column.
    '''
    
    # create a subset of train with the specified variables
    X = train_scaled[[variable1, variable2, variable3]]
    
    # initiate and fit kmeans
    kmeans = KMeans(n_clusters=3, random_state=42) 
    kmeans.fit(X)
    train_scaled['cluster'] = kmeans.predict(X)
    
    # Create centroids dataframe for potential use or display
    centroids = pd.DataFrame(kmeans.cluster_centers_, columns=[variable1, variable2, variable3])
    
    # Rename cluster labels for clarity in visualization
    train_scaled['cluster'] = 'cluster_' + train_scaled.cluster.astype(str)
    
    #Plot the actual distribution of quality next to generated clusters
    fig, axes = plt.subplots(1, 2, figsize=(16, 9))
    
    sns.scatterplot(ax=axes[0], x=variable1, y=variable2, hue='quality', palette='colorblind', data=train_scaled)
    axes[0].set_title("Actual Distribution of Quality Bins")
    
    sns.scatterplot(ax=axes[1], x=variable1, y=variable2, hue='cluster', palette='colorblind', data=train_scaled)
    axes[1].set_title("Clusters Generated by KMeans")
    
    plt.show()
    
    return train_scaled

# %% [markdown]
# # Cluster 1: 'fixed_acidity', 'residual_sugar', 'density'

# %%
new_train1 = find_clusters(train_scaled, 'fixed_acidity', 'residual_sugar', 'density')

# %%
# Created dummy columns for 'cluster' column
cluster_dummies = pd.get_dummies(new_train1['cluster'], prefix='cluster', drop_first=True)

# Appended these dummy columns to the new_train1 dataframe
new_train1 = pd.concat([new_train1, cluster_dummies], axis=1)

# %%
new_train1.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  density_sulfates_ratio  chlorides_sulfates_ratio  \
# 3761   0.125000  ...                0.438989                  0.291341
# 3740   0.159091  ...                0.373711                  0.149847
#
#      residual_sugar_percentage alcohol_chlorides_ratio  \
# 3761                  0.020075                0.062414
# 3740                  0.158298                0.105107
#
#       density_sulfur_dioxide_ratio  ph_sulfur_dioxide_ratio  \
# 3761                      0.035256                 0.029406
# 3740                      0.034612                 0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  cluster_cluster_1  \
# 3761                    0.230453  cluster_2              False
# 3740                    0.031590  cluster_0              False
#
#       cluster_cluster_2
# 3761               True
# 3740              False
#
# [2 rows x 42 columns]

# %%
train_scaled = new_train1.rename(columns={
    'cluster_cluster_1': 'composite_cluster_0',
    'cluster_cluster_2': 'composite_cluster_1'
})

# %%
train_scaled.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  density_sulfates_ratio  chlorides_sulfates_ratio  \
# 3761   0.125000  ...                0.438989                  0.291341
# 3740   0.159091  ...                0.373711                  0.149847
#
#      residual_sugar_percentage alcohol_chlorides_ratio  \
# 3761                  0.020075                0.062414
# 3740                  0.158298                0.105107
#
#       density_sulfur_dioxide_ratio  ph_sulfur_dioxide_ratio  \
# 3761                      0.035256                 0.029406
# 3740                      0.034612                 0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  composite_cluster_0  \
# 3761                    0.230453  cluster_2                False
# 3740                    0.031590  cluster_0                False
#
#       composite_cluster_1
# 3761                 True
# 3740                False
#
# [2 rows x 42 columns]

# %% [markdown]
# # Cluster 3: 'ph', 'density', 'chlorides'

# %%
new_train2 = find_clusters(train_scaled, 'ph', 'density', 'chlorides')

# %%
# Create dummy columns for the 'cluster' column
cluster_dummies = pd.get_dummies(new_train2['cluster'], prefix='cluster', drop_first=True)

# Append these dummy columns to the new_train2 dataframe
new_train2 = pd.concat([new_train2, cluster_dummies], axis=1)

# %%
new_train2.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  residual_sugar_percentage  alcohol_chlorides_ratio  \
# 3761   0.125000  ...                   0.020075                 0.062414
# 3740   0.159091  ...                   0.158298                 0.105107
#
#      density_sulfur_dioxide_ratio ph_sulfur_dioxide_ratio  \
# 3761                     0.035256                0.029406
# 3740                     0.034612                0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  composite_cluster_0  \
# 3761                    0.230453  cluster_1                False
# 3740                    0.031590  cluster_0                False
#
#       composite_cluster_1  cluster_cluster_1  cluster_cluster_2
# 3761                 True               True              False
# 3740                False              False              False
#
# [2 rows x 44 columns]

# %%
train_scaled = new_train1.rename(columns={
    'cluster_cluster_1': 'composite_cluster_2',
    'cluster_cluster_2': 'composite_cluster_3'
})

# %%
train_scaled.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  density_sulfates_ratio  chlorides_sulfates_ratio  \
# 3761   0.125000  ...                0.438989                  0.291341
# 3740   0.159091  ...                0.373711                  0.149847
#
#      residual_sugar_percentage alcohol_chlorides_ratio  \
# 3761                  0.020075                0.062414
# 3740                  0.158298                0.105107
#
#       density_sulfur_dioxide_ratio  ph_sulfur_dioxide_ratio  \
# 3761                      0.035256                 0.029406
# 3740                      0.034612                 0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  composite_cluster_2  \
# 3761                    0.230453  cluster_2                False
# 3740                    0.031590  cluster_0                False
#
#       composite_cluster_3
# 3761                 True
# 3740                False
#
# [2 rows x 42 columns]

# %% [markdown]
# # Cluster 3: 'residual_sugar', 'citric_acid', 'quality'

# %%
new_train3 = find_clusters(train_scaled, 'residual_sugar', 'citric_acid', 'quality')

# %%
# dummy columns for the 'cluster' column
cluster_dummies_3 = pd.get_dummies(new_train3['cluster'], prefix='cluster', drop_first=True)

# Appended these dummy columns to the new_train3 dataframe
new_train3 = pd.concat([new_train3, cluster_dummies_3], axis=1)

# %%
new_train3.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  residual_sugar_percentage  alcohol_chlorides_ratio  \
# 3761   0.125000  ...                   0.020075                 0.062414
# 3740   0.159091  ...                   0.158298                 0.105107
#
#      density_sulfur_dioxide_ratio ph_sulfur_dioxide_ratio  \
# 3761                     0.035256                0.029406
# 3740                     0.034612                0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  composite_cluster_2  \
# 3761                    0.230453  cluster_1                False
# 3740                    0.031590  cluster_1                False
#
#       composite_cluster_3  cluster_cluster_1  cluster_cluster_2
# 3761                 True               True              False
# 3740                False               True              False
#
# [2 rows x 44 columns]

# %%
train_scaled = new_train3.rename(columns={
    'composite_cluster_2': 'composite_cluster_4',
    'composite_cluster_3': 'composite_cluster_5',
    'cluster_cluster_1': 'composite_cluster_6',
    'cluster_cluster_2': 'composite_cluster_7'
})

# %%
train_scaled.head(2)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3761       0.516949          0.273333     0.186992        0.027607   0.129568
# 3740       0.330508          0.133333     0.284553        0.225460   0.078073
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        ph  \
# 3761             0.123711              0.322485  0.148255  0.023622
# 3740             0.206186              0.328402  0.244650  0.417323
#
#       sulphates  ...  residual_sugar_percentage  alcohol_chlorides_ratio  \
# 3761   0.125000  ...                   0.020075                 0.062414
# 3740   0.159091  ...                   0.158298                 0.105107
#
#      density_sulfur_dioxide_ratio ph_sulfur_dioxide_ratio  \
# 3761                     0.035256                0.029406
# 3740                     0.034612                0.036939
#
#       sulfur_dioxide_sugar_ratio    cluster  composite_cluster_4  \
# 3761                    0.230453  cluster_1                False
# 3740                    0.031590  cluster_1                False
#
#       composite_cluster_5  composite_cluster_6  composite_cluster_7
# 3761                 True                 True                False
# 3740                False                 True                False
#
# [2 rows x 44 columns]
